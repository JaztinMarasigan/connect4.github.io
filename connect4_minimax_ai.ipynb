# %% [markdown]
# # Connect Four AI (Minimax + Alpha–Beta)
#
# This notebook implements a playable Connect Four with:
# - A clean board representation
# - Depth-limited **Minimax**
# - **Alpha–Beta pruning** with move ordering
# - A practical **heuristic evaluation** (window scoring + center control)
# - Simple **CLI-style** play and **experiments** (nodes expanded, timing)

# %% [markdown]
# ## How to use
# - Run cells from top to bottom.
# - Use `play_human_vs_ai()` to play against the AI in the terminal-like prompt.
# - Use the **Experiments** section to compare Minimax vs Alpha–Beta.

# %%
import math, random, time
from dataclasses import dataclass
from typing import List, Optional, Tuple
import matplotlib.pyplot as plt

ROWS, COLS = 6, 7
EMPTY, MAX, MIN = 0, 1, -1   # MAX is the AI by default
CENTER_COL = COLS // 2

# For instrumentation (experiments)
class Counter:
    def __init__(self):
        self.nodes = 0
        self.cutoffs = 0
    def reset(self):
        self.nodes = 0
        self.cutoffs = 0

global_counter = Counter()

# %% [markdown]
# ## Board Representation
# We use a simple 2D list: `board[r][c]` with values in `{0, 1, -1}` for empty/MAX/MIN.

# %%
@dataclass
class State:
    board: List[List[int]]
    player: int   # whose turn: MAX (1) or MIN (-1)

def new_state() -> State:
    return State([[EMPTY for _ in range(COLS)] for _ in range(ROWS)], MAX)

def copy_state(s: State) -> State:
    return State([row[:] for row in s.board], s.player)

def actions(s: State) -> List[int]:
    return [c for c in range(COLS) if s.board[0][c] == EMPTY]

def result(s: State, a: int) -> State:
    ns = copy_state(s)
    # drop disc in column a
    for r in range(ROWS-1, -1, -1):
        if ns.board[r][a] == EMPTY:
            ns.board[r][a] = s.player
            break
    ns.player = -s.player
    return ns

def in_bounds(r,c): 
    return 0 <= r < ROWS and 0 <= c < COLS

# Winner / terminal detection
DIRS = [(0,1),(1,0),(1,1),(1,-1)]

def line_winner_at(board, r, c):
    player = board[r][c]
    if player == EMPTY: 
        return None
    for dr, dc in DIRS:
        count = 1
        for k in range(1,4):
            rr, cc = r + dr*k, c + dc*k
            if in_bounds(rr,cc) and board[rr][cc] == player:
                count += 1
            else:
                break
        if count >= 4:
            return player
    return None

def winner(s: State) -> Optional[int]:
    for r in range(ROWS):
        for c in range(COLS):
            w = line_winner_at(s.board, r, c)
            if w:
                return w
    return None

def terminal_test(s: State) -> bool:
    return winner(s) is not None or all(s.board[0][c] != EMPTY for c in range(COLS))

def utility(s: State) -> int:
    w = winner(s)
    if w == MAX: return 10**9
    if w == MIN: return -10**9
    return 0

def print_board(s: State):
    symbols = {EMPTY:'.', MAX:'X', MIN:'O'}
    for r in range(ROWS):
        print(' '.join(symbols[v] for v in s.board[r]))
    print('0 1 2 3 4 5 6')

# %% [markdown]
# ## Heuristic Evaluation
# We score all contiguous windows of 4 cells horizontally, vertically, and diagonally.
# Features:
# - Window patterns (3-in-a-row with one empty, 2-in-a-row with two empty, etc.)
# - Center column bias (favor occupying the middle)
# - Immediate win/loss are handled by `utility()` when terminal; we also include
#   **near-term threats** implicitly through window scoring.

# %%
def score_window(window: List[int], player: int) -> int:
    opp = -player
    count_p = window.count(player)
    count_o = window.count(opp)
    empties = window.count(EMPTY)
    # Blocked window: both players present
    if count_p > 0 and count_o > 0:
        return 0
    # Scoring (tune as needed)
    if count_p == 3 and empties == 1: return 5
    if count_p == 2 and empties == 2: return 2
    if count_o == 3 and empties == 1: return -5
    if count_o == 2 and empties == 2: return -2
    return 0

def evaluate(s: State, player=MAX) -> int:
    if terminal_test(s):
        return utility(s)  # strong terminal values

    total = 0
    # Center column bias
    center_col_vals = [s.board[r][CENTER_COL] for r in range(ROWS)]
    total += 3 * center_col_vals.count(player)
    total -= 3 * center_col_vals.count(-player)

    # Horizontal
    for r in range(ROWS):
        for c in range(COLS-3):
            w = [s.board[r][c+i] for i in range(4)]
            total += score_window(w, player)
    # Vertical
    for r in range(ROWS-3):
        for c in range(COLS):
            w = [s.board[r+i][c] for i in range(4)]
            total += score_window(w, player)
    # Diagonal down-right
    for r in range(ROWS-3):
        for c in range(COLS-3):
            w = [s.board[r+i][c+i] for i in range(4)]
            total += score_window(w, player)
    # Diagonal up-right
    for r in range(3, ROWS):
        for c in range(COLS-3):
            w = [s.board[r-i][c+i] for i in range(4)]
            total += score_window(w, player)
    return total

# %% [markdown]
# ## Move Ordering
# Try the center column first, then increasing distance from center. Optionally,
# do a shallow evaluation of each child and sort by that score to improve pruning.

# %%
DEFAULT_ORDER = [3,2,4,1,5,0,6]

def ordered_actions(s: State) -> List[int]:
    legal = actions(s)
    # Start with the default center-first heuristic
    legal.sort(key=lambda c: DEFAULT_ORDER.index(c))
    # Enhanced: sort by a 1-ply heuristic lookahead
    scored = []
    for a in legal:
        ns = result(s, a)
        scored.append((evaluate(ns, MAX), a) if s.player == MAX else (evaluate(ns, MIN), a))
    reverse = (s.player == MAX)
    scored.sort(key=lambda t: t[0], reverse=reverse)
    return [a for _, a in scored]

# %% [markdown]
# ## Search: Minimax and Alpha–Beta
# Depth-limited search; we return `(score, action)` from the root.

# %%
def minimax(s: State, depth: int, player_view=MAX) -> Tuple[int, Optional[int]]:
    global_counter.nodes += 1
    if depth == 0 or terminal_test(s):
        return evaluate(s, player_view), None
    if s.player == MAX:
        best = (-math.inf, None)
        for a in actions(s):
            v, _ = minimax(result(s, a), depth-1, player_view)
            if v > best[0]:
                best = (v, a)
        return best
    else:
        best = (math.inf, None)
        for a in actions(s):
            v, _ = minimax(result(s, a), depth-1, player_view)
            if v < best[0]:
                best = (v, a)
        return best

def alphabeta(s: State, depth: int, alpha=-math.inf, beta=math.inf, player_view=MAX) -> Tuple[int, Optional[int]]:
    global_counter.nodes += 1
    if depth == 0 or terminal_test(s):
        return evaluate(s, player_view), None
    if s.player == MAX:
        best = (-math.inf, None)
        for a in ordered_actions(s):
            v, _ = alphabeta(result(s, a), depth-1, alpha, beta, player_view)
            if v > best[0]:
                best = (v, a)
            alpha = max(alpha, v)
            if alpha >= beta:
                global_counter.cutoffs += 1
                break
        return best
    else:
        best = (math.inf, None)
        for a in ordered_actions(s):
            v, _ = alphabeta(result(s, a), depth-1, alpha, beta, player_view)
            if v < best[0]:
                best = (v, a)
            beta = min(beta, v)
            if alpha >= beta:
                global_counter.cutoffs += 1
                break
        return best

# %% [markdown]
# ## Play: Human vs AI (CLI)
# Run `play_human_vs_ai(depth=6, use_alphabeta=True)` in a cell to play.

# %%
def play_human_vs_ai(depth=6, human_plays=MIN, use_alphabeta=True):
    s = new_state()
    while not terminal_test(s):
        print_board(s)
        if s.player == human_plays:
            legal = actions(s)
            try:
                a = int(input(f"Your move {legal}: "))
            except Exception:
                print("Please enter a column number.")
                continue
            if a not in legal:
                print("Illegal move. Try again.")
                continue
            s = result(s, a)
        else:
            global_counter.reset()
            start = time.time()
            if use_alphabeta:
                score, a = alphabeta(s, depth)
            else:
                score, a = minimax(s, depth)
            elapsed = time.time() - start
            print(f"AI selects column {a} (score={score}, nodes={global_counter.nodes}, cutoffs={global_counter.cutoffs}, time={elapsed:.3f}s)")
            s = result(s, a)
    print_board(s)
    w = winner(s)
    if w == MAX: print("AI (MAX/X) wins!")
    elif w == MIN: print("Human (MIN/O) wins!")
    else: print("Draw.")

# %% [markdown]
# ## Experiments
# Measure nodes/time vs depth and compare Minimax vs Alpha–Beta.

# %%
def pick_ai_move(search_fn, s: State, depth: int) -> Tuple[int, int, float, int]:
    global_counter.reset()
    t0 = time.time()
    score, a = search_fn(s, depth)
    dt = time.time() - t0
    return global_counter.nodes, a, dt, global_counter.cutoffs

def experiment(depths=(3,4,5,6)):
    results = []
    for d in depths:
        s = new_state()
        # Randomize a few opening moves to avoid trivial empty-board symmetry
        for _ in range(2):
            if terminal_test(s): break
            s = result(s, random.choice(actions(s)))
        nodes_minimax, _, t_minimax, _ = pick_ai_move(lambda st,dep: minimax(st,dep), s, d)
        nodes_ab, _, t_ab, cut_ab = pick_ai_move(lambda st,dep: alphabeta(st,dep), s, d)
        results.append((d, nodes_minimax, t_minimax, nodes_ab, t_ab, cut_ab))
    return results

res = experiment(depths=(3,4,5))
res
# Out:
# [(3, 400, 0.02244877815246582, 110, 0.011080026626586914, 13),
#  (4, 2801, 0.06981086730957031, 390, 0.021848678588867188, 76),
#  (5, 19608, 0.38693976402282715, 2212, 0.1416170597076416, 453)]

# %% [markdown]
# ### Plot: Nodes vs Depth

# %%
def plot_nodes(results):
    depths = [r[0] for r in results]
    nodes_mm = [r[1] for r in results]
    nodes_ab = [r[3] for r in results]
    plt.figure()
    plt.plot(depths, nodes_mm, marker='o', label='Minimax')
    plt.plot(depths, nodes_ab, marker='o', label='Alpha-Beta')
    plt.xlabel('Depth')
    plt.ylabel('Nodes Expanded')
    plt.title('Nodes vs Depth')
    plt.legend()
    plt.show()

plot_nodes(res)

# %% [markdown]
# ### Plot: Time vs Depth

# %%
def plot_time(results):
    depths = [r[0] for r in results]
    t_mm = [r[2] for r in results]
    t_ab = [r[4] for r in results]
    plt.figure()
    plt.plot(depths, t_mm, marker='o', label='Minimax')
    plt.plot(depths, t_ab, marker='o', label='Alpha-Beta')
    plt.xlabel('Depth')
    plt.ylabel('Time (s)')
    plt.title('Time vs Depth')
    plt.legend()
    plt.show()

plot_time(res)

# %% [markdown]
# ## Quick Sanity Test
# Let the AI (MAX) choose a move from the initial board at depth 5.

# %%
s0 = new_state()
print_board(s0)
nodes, move, elapsed, cutoffs = pick_ai_move(lambda st,dep: alphabeta(st,dep), s0, depth=5)
print(f"AI suggests column {move} | nodes={nodes}, cutoffs={cutoffs}, time={elapsed:.3f}s")
# Out:
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# 0 1 2 3 4 5 6
# AI suggests column 3 | nodes=1359, cutoffs=225, time=0.117s

# %%
play_human_vs_ai(depth=6, use_alphabeta=True)
# Out:
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# 0 1 2 3 4 5 6
# AI selects column 3 (score=0, nodes=4540, cutoffs=785, time=0.312s)
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . X . . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 3, 4, 5, 6]:  3
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . O . . .
# . . . X . . .
# 0 1 2 3 4 5 6
# AI selects column 3 (score=-2, nodes=9217, cutoffs=1783, time=0.622s)
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . X . . .
# . . . O . . .
# . . . X . . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 3, 4, 5, 6]:  4
# . . . . . . .
# . . . . . . .
# . . . . . . .
# . . . X . . .
# . . . O . . .
# . . . X O . .
# 0 1 2 3 4 5 6
# AI selects column 3 (score=9, nodes=4297, cutoffs=1027, time=0.353s)
# . . . . . . .
# . . . . . . .
# . . . X . . .
# . . . X . . .
# . . . O . . .
# . . . X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 3, 4, 5, 6]:  2
# . . . . . . .
# . . . . . . .
# . . . X . . .
# . . . X . . .
# . . . O . . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 2 (score=13, nodes=4523, cutoffs=1202, time=0.425s)
# . . . . . . .
# . . . . . . .
# . . . X . . .
# . . . X . . .
# . . X O . . .
# . . O X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 3, 4, 5, 6]:  2
# . . . . . . .
# . . . . . . .
# . . . X . . .
# . . O X . . .
# . . X O . . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 3 (score=15, nodes=3306, cutoffs=953, time=0.320s)
# . . . . . . .
# . . . X . . .
# . . . X . . .
# . . O X . . .
# . . X O . . .
# . . O X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 3, 4, 5, 6]:  3
# . . . O . . .
# . . . X . . .
# . . . X . . .
# . . O X . . .
# . . X O . . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 2 (score=18, nodes=2218, cutoffs=637, time=0.226s)
# . . . O . . .
# . . . X . . .
# . . X X . . .
# . . O X . . .
# . . X O . . .
# . . O X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 4, 5, 6]:  4
# . . . O . . .
# . . . X . . .
# . . X X . . .
# . . O X . . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 4 (score=19, nodes=2889, cutoffs=846, time=0.297s)
# . . . O . . .
# . . . X . . .
# . . X X . . .
# . . O X X . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 4, 5, 6]:  4
# . . . O . . .
# . . . X . . .
# . . X X O . .
# . . O X X . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 2 (score=19, nodes=3335, cutoffs=956, time=0.338s)
# . . . O . . .
# . . X X . . .
# . . X X O . .
# . . O X X . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 4, 5, 6]:  4
# . . . O . . .
# . . X X O . .
# . . X X O . .
# . . O X X . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 4 (score=19, nodes=2363, cutoffs=718, time=0.250s)
# . . . O X . .
# . . X X O . .
# . . X X O . .
# . . O X X . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# Your move [0, 1, 2, 5, 6]:  2
# . . O O X . .
# . . X X O . .
# . . X X O . .
# . . O X X . .
# . . X O O . .
# . . O X O . .
# 0 1 2 3 4 5 6
# AI selects column 6 (score=22, nodes=481, cutoffs=163, time=0.081s)
# . . O O X . .
# . . X X O . .
# . . X X O . .
# . . O X X . .
# . . X O O . .
# . . O X O . X
# 0 1 2 3 4 5 6
# Your move [0, 1, 5, 6]:  6
# . . O O X . .
# . . X X O . .
# . . X X O . .
# . . O X X . .
# . . X O O . O
# . . O X O . X
# 0 1 2 3 4 5 6
# AI selects column 6 (score=25, nodes=327, cutoffs=111, time=0.064s)
# . . O O X . .
# . . X X O . .
# . . X X O . .
# . . O X X . X
# . . X O O . O
# . . O X O . X
# 0 1 2 3 4 5 6
# Your move [0, 1, 5, 6]:  6
# . . O O X . .
# . . X X O . .
# . . X X O . O
# . . O X X . X
# . . X O O . O
# . . O X O . X
# 0 1 2 3 4 5 6
# AI selects column 1 (score=30, nodes=274, cutoffs=99, time=0.054s)
# . . O O X . .
# . . X X O . .
# . . X X O . O
# . . O X X . X
# . . X O O . O
# . X O X O . X
# 0 1 2 3 4 5 6
# Your move [0, 1, 5, 6]:  6
# . . O O X . .
# . . X X O . O
# . . X X O . O
# . . O X X . X
# . . X O O . O
# . X O X O . X
# 0 1 2 3 4 5 6
# AI selects column 6 (score=31, nodes=192, cutoffs=69, time=0.044s)
# . . O O X . X
# . . X X O . O
# . . X X O . O
# . . O X X . X
# . . X O O . O
# . X O X O . X
# 0 1 2 3 4 5 6
# Your move [0, 1, 5]:  0
# . . O O X . X
# . . X X O . O
# . . X X O . O
# . . O X X . X
# . . X O O . O
# O X O X O . X
# 0 1 2 3 4 5 6
# AI selects column 0 (score=36, nodes=67, cutoffs=26, time=0.014s)
# . . O O X . X
# . . X X O . O
# . . X X O . O
# . . O X X . X
# X . X O O . O
# O X O X O . X
# 0 1 2 3 4 5 6
# Your move [0, 1, 5]:  0
# . . O O X . X
# . . X X O . O
# . . X X O . O
# O . O X X . X
# X . X O O . O
# O X O X O . X
# 0 1 2 3 4 5 6
# AI selects column 0 (score=1000000000, nodes=28, cutoffs=10, time=0.005s)
# . . O O X . X
# . . X X O . O
# X . X X O . O
# O . O X X . X
# X . X O O . O
# O X O X O . X
# 0 1 2 3 4 5 6
# Your move [0, 1, 5]:  0
# . . O O X . X
# O . X X O . O
# X . X X O . O
# O . O X X . X
# X . X O O . O
# O X O X O . X
# 0 1 2 3 4 5 6
# AI selects column 0 (score=1000000000, nodes=16, cutoffs=5, time=0.004s)
# X . O O X . X
# O . X X O . O
# X . X X O . O
# O . O X X . X
# X . X O O . O
# O X O X O . X
# 0 1 2 3 4 5 6
# Your move [1, 5]:  5
# X . O O X . X
# O . X X O . O
# X . X X O . O
# O . O X X . X
# X . X O O . O
# O X O X O O X
# 0 1 2 3 4 5 6
# AI selects column 5 (score=1000000000, nodes=4, cutoffs=1, time=0.001s)
# X . O O X . X
# O . X X O . O
# X . X X O . O
# O . O X X . X
# X . X O O X O
# O X O X O O X
# 0 1 2 3 4 5 6
# AI (MAX/X) wins!

# %%
import itertools
_trace_id = itertools.count()

def trace_alphabeta(s: State, depth: int, alpha=-math.inf, beta=math.inf, player_view=MAX, indent=0):
    """Returns (value, action) and prints a trace line-by-line.
    Uses ordered_actions() for child ordering so trace matches actual search order."""
    nid = next(_trace_id)
    global_counter.nodes += 1
    prefix = "  " * indent
    node_player = "MAX" if s.player == MAX else "MIN"
    acts = actions(s)
    print(f"{prefix}Node {nid}: depth={depth} player={node_player} alpha={alpha} beta={beta} legal={acts}")
    if depth == 0 or terminal_test(s):
        val = evaluate(s, player_view)
        print(f"{prefix}  -> Leaf eval = {val}")
        return val, None

    if s.player == MAX:
        best_val, best_act = -math.inf, None
        for a in ordered_actions(s):
            print(f"{prefix}  -> Explore action {a}")
            v, _ = trace_alphabeta(result(s, a), depth-1, alpha, beta, player_view, indent+2)
            print(f"{prefix}  <- Action {a} returned {v}")
            if v > best_val:
                best_val, best_act = v, a
            alpha = max(alpha, v)
            if alpha >= beta:
                global_counter.cutoffs += 1
                print(f"{prefix}  ## CUTOFF (alpha={alpha} >= beta={beta}) after action {a}")
                break
        print(f"{prefix}  => Node {nid} returns (val={best_val}, act={best_act})")
        return best_val, best_act
    else:
        best_val, best_act = math.inf, None
        for a in ordered_actions(s):
            print(f"{prefix}  -> Explore action {a}")
            v, _ = trace_alphabeta(result(s, a), depth-1, alpha, beta, player_view, indent+2)
            print(f"{prefix}  <- Action {a} returned {v}")
            if v < best_val:
                best_val, best_act = v, a
            beta = min(beta, v)
            if alpha >= beta:
                global_counter.cutoffs += 1
                print(f"{prefix}  ## CUTOFF (alpha={alpha} >= beta={beta}) after action {a}")
                break
        print(f"{prefix}  => Node {nid} returns (val={best_val}, act={best_act})")
        return best_val, best_act

def run_trace(s: State, depth: int):
    global_counter.reset()
    # reset trace id
    global _trace_id
    _trace_id = itertools.count()
    print("=== TRACE START ===")
    val, act = trace_alphabeta(s, depth, -math.inf, math.inf, player_view=MAX, indent=0)
    print("=== TRACE END ===")
    print(f"Result: chosen action={act}, value={val}, nodes={global_counter.nodes}, cutoffs={global_counter.cutoffs}")
#

# %%
# run this after the cell above
s0 = new_state()          # initial board
run_trace(s0, depth=4)    # choose depth small enough to keep trace readable
# Out:
# === TRACE START ===
# Node 0: depth=4 player=MAX alpha=-inf beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#   -> Explore action 3
#     Node 1: depth=3 player=MIN alpha=-inf beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 2: depth=2 player=MAX alpha=-inf beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 3: depth=1 player=MIN alpha=-inf beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 4: depth=0 player=MAX alpha=-inf beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 4 returned 8
#               -> Explore action 1
#                 Node 5: depth=0 player=MAX alpha=-inf beta=8 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 1 returned 8
#               -> Explore action 5
#                 Node 6: depth=0 player=MAX alpha=-inf beta=8 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 5 returned 8
#               -> Explore action 0
#                 Node 7: depth=0 player=MAX alpha=-inf beta=8 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 0 returned 8
#               -> Explore action 6
#                 Node 8: depth=0 player=MAX alpha=-inf beta=8 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 6 returned 8
#               -> Explore action 2
#                 Node 9: depth=0 player=MAX alpha=-inf beta=8 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 2 returned 6
#               -> Explore action 3
#                 Node 10: depth=0 player=MAX alpha=-inf beta=6 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 3 returned 3
#               => Node 3 returns (val=3, act=3)
#           <- Action 3 returned 3
#           -> Explore action 2
#             Node 11: depth=1 player=MIN alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 12: depth=0 player=MAX alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 2 returned 5
#               -> Explore action 4
#                 Node 13: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 4 returned 5
#               -> Explore action 1
#                 Node 14: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 5
#                 Node 15: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 5 returned 5
#               -> Explore action 0
#                 Node 16: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 6
#                 Node 17: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 6 returned 5
#               -> Explore action 3
#                 Node 18: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 3 returned 0
#               ## CUTOFF (alpha=3 >= beta=0) after action 3
#               => Node 11 returns (val=0, act=3)
#           <- Action 2 returned 0
#           -> Explore action 4
#             Node 19: depth=1 player=MIN alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 20: depth=0 player=MAX alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 4 returned 5
#               -> Explore action 1
#                 Node 21: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 0
#                 Node 22: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 2
#                 Node 23: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 2 returned 3
#               ## CUTOFF (alpha=3 >= beta=3) after action 2
#               => Node 19 returns (val=3, act=2)
#           <- Action 4 returned 3
#           -> Explore action 5
#             Node 24: depth=1 player=MIN alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 25: depth=0 player=MAX alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 5
#                 Node 26: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 5 returned 5
#               -> Explore action 0
#                 Node 27: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 2
#                 Node 28: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 2 returned 3
#               ## CUTOFF (alpha=3 >= beta=3) after action 2
#               => Node 24 returns (val=3, act=2)
#           <- Action 5 returned 3
#           -> Explore action 6
#             Node 29: depth=1 player=MIN alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 30: depth=0 player=MAX alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 0
#                 Node 31: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 6
#                 Node 32: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 6 returned 5
#               -> Explore action 2
#                 Node 33: depth=0 player=MAX alpha=3 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 2 returned 3
#               ## CUTOFF (alpha=3 >= beta=3) after action 2
#               => Node 29 returns (val=3, act=2)
#           <- Action 6 returned 3
#           -> Explore action 1
#             Node 34: depth=1 player=MIN alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 35: depth=0 player=MAX alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 4 returned 3
#               ## CUTOFF (alpha=3 >= beta=3) after action 4
#               => Node 34 returns (val=3, act=4)
#           <- Action 1 returned 3
#           -> Explore action 0
#             Node 36: depth=1 player=MIN alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 37: depth=0 player=MAX alpha=3 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 4 returned 3
#               ## CUTOFF (alpha=3 >= beta=3) after action 4
#               => Node 36 returns (val=3, act=4)
#           <- Action 0 returned 3
#           => Node 2 returns (val=3, act=3)
#       <- Action 2 returned 3
#       -> Explore action 4
#         Node 38: depth=2 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 39: depth=1 player=MIN alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 40: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 2 returned 8
#               -> Explore action 1
#                 Node 41: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 1 returned 8
#               -> Explore action 5
#                 Node 42: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 5 returned 8
#               -> Explore action 0
#                 Node 43: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 0 returned 8
#               -> Explore action 6
#                 Node 44: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 6 returned 8
#               -> Explore action 4
#                 Node 45: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 4 returned 6
#               -> Explore action 3
#                 Node 46: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 3 returned 3
#               => Node 39 returns (val=3, act=3)
#           <- Action 3 returned 3
#           ## CUTOFF (alpha=3 >= beta=3) after action 3
#           => Node 38 returns (val=3, act=3)
#       <- Action 4 returned 3
#       -> Explore action 1
#         Node 47: depth=2 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 48: depth=1 player=MIN alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 49: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 2 returned 8
#               -> Explore action 4
#                 Node 50: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 4 returned 8
#               -> Explore action 5
#                 Node 51: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 5 returned 8
#               -> Explore action 0
#                 Node 52: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 0 returned 8
#               -> Explore action 6
#                 Node 53: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 6 returned 8
#               -> Explore action 1
#                 Node 54: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 1 returned 6
#               -> Explore action 3
#                 Node 55: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 3 returned 1
#               => Node 48 returns (val=1, act=3)
#           <- Action 3 returned 1
#           -> Explore action 4
#             Node 56: depth=1 player=MIN alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 57: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 4 returned 7
#               -> Explore action 0
#                 Node 58: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 0 returned 7
#               -> Explore action 2
#                 Node 59: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 2 returned 5
#               -> Explore action 1
#                 Node 60: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 6
#                 Node 61: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 6 returned 5
#               -> Explore action 3
#                 Node 62: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 3 returned 4
#               -> Explore action 5
#                 Node 63: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 5 returned 3
#               => Node 56 returns (val=3, act=5)
#           <- Action 4 returned 3
#           ## CUTOFF (alpha=3 >= beta=3) after action 4
#           => Node 47 returns (val=3, act=4)
#       <- Action 1 returned 3
#       -> Explore action 5
#         Node 64: depth=2 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 65: depth=1 player=MIN alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 66: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 2 returned 8
#               -> Explore action 4
#                 Node 67: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 4 returned 8
#               -> Explore action 1
#                 Node 68: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 1 returned 8
#               -> Explore action 0
#                 Node 69: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 0 returned 8
#               -> Explore action 6
#                 Node 70: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 8
#               <- Action 6 returned 8
#               -> Explore action 5
#                 Node 71: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 5 returned 6
#               -> Explore action 3
#                 Node 72: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 3 returned 1
#               => Node 65 returns (val=1, act=3)
#           <- Action 3 returned 1
#           -> Explore action 2
#             Node 73: depth=1 player=MIN alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 74: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 2 returned 7
#               -> Explore action 6
#                 Node 75: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 6 returned 7
#               -> Explore action 4
#                 Node 76: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 4 returned 5
#               -> Explore action 5
#                 Node 77: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 5 returned 5
#               -> Explore action 0
#                 Node 78: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 3
#                 Node 79: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 3 returned 4
#               -> Explore action 1
#                 Node 80: depth=0 player=MAX alpha=1 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 1 returned 3
#               => Node 73 returns (val=3, act=1)
#           <- Action 2 returned 3
#           ## CUTOFF (alpha=3 >= beta=3) after action 2
#           => Node 64 returns (val=3, act=2)
#       <- Action 5 returned 3
#       -> Explore action 0
#         Node 81: depth=2 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 4
#             Node 82: depth=1 player=MIN alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 83: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 9
#               <- Action 4 returned 9
#               -> Explore action 1
#                 Node 84: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 1 returned 7
#               -> Explore action 0
#                 Node 85: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 0 returned 7
#               -> Explore action 6
#                 Node 86: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 6 returned 7
#               -> Explore action 3
#                 Node 87: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 3 returned 6
#               -> Explore action 2
#                 Node 88: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 2 returned 5
#               -> Explore action 5
#                 Node 89: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 5 returned 5
#               => Node 82 returns (val=5, act=2)
#           <- Action 4 returned 5
#           ## CUTOFF (alpha=5 >= beta=3) after action 4
#           => Node 81 returns (val=5, act=4)
#       <- Action 0 returned 5
#       -> Explore action 6
#         Node 90: depth=2 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 2
#             Node 91: depth=1 player=MIN alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 92: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 9
#               <- Action 2 returned 9
#               -> Explore action 5
#                 Node 93: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 5 returned 7
#               -> Explore action 0
#                 Node 94: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 0 returned 7
#               -> Explore action 6
#                 Node 95: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 6 returned 7
#               -> Explore action 3
#                 Node 96: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 3 returned 6
#               -> Explore action 4
#                 Node 97: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 4 returned 5
#               -> Explore action 1
#                 Node 98: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               => Node 91 returns (val=5, act=4)
#           <- Action 2 returned 5
#           ## CUTOFF (alpha=5 >= beta=3) after action 2
#           => Node 90 returns (val=5, act=2)
#       <- Action 6 returned 5
#       -> Explore action 3
#         Node 99: depth=2 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 2
#             Node 100: depth=1 player=MIN alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 6
#                 Node 101: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 6 returned 6
#               -> Explore action 5
#                 Node 102: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 5 returned 4
#               -> Explore action 0
#                 Node 103: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 0 returned 4
#               -> Explore action 1
#                 Node 104: depth=0 player=MAX alpha=-inf beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 1 returned 2
#               -> Explore action 3
#                 Node 105: depth=0 player=MAX alpha=-inf beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 3 returned 1
#               -> Explore action 2
#                 Node 106: depth=0 player=MAX alpha=-inf beta=1 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               -> Explore action 4
#                 Node 107: depth=0 player=MAX alpha=-inf beta=0 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               => Node 100 returns (val=0, act=2)
#           <- Action 2 returned 0
#           -> Explore action 4
#             Node 108: depth=1 player=MIN alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 0
#                 Node 109: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 6
#               <- Action 0 returned 6
#               -> Explore action 1
#                 Node 110: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 1 returned 4
#               -> Explore action 6
#                 Node 111: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 6 returned 4
#               -> Explore action 5
#                 Node 112: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 3
#                 Node 113: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 3 returned 1
#               -> Explore action 2
#                 Node 114: depth=0 player=MAX alpha=0 beta=1 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 108 returns (val=0, act=2)
#           <- Action 4 returned 0
#           -> Explore action 1
#             Node 115: depth=1 player=MIN alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 116: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 5 returned 4
#               -> Explore action 6
#                 Node 117: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 6 returned 4
#               -> Explore action 0
#                 Node 118: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 0 returned 2
#               -> Explore action 4
#                 Node 119: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 115 returns (val=0, act=4)
#           <- Action 1 returned 0
#           -> Explore action 5
#             Node 120: depth=1 player=MIN alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 121: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 1 returned 4
#               -> Explore action 0
#                 Node 122: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 0 returned 4
#               -> Explore action 6
#                 Node 123: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 124: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 120 returns (val=0, act=2)
#           <- Action 5 returned 0
#           -> Explore action 3
#             Node 125: depth=1 player=MIN alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 126: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 1 returned 3
#               -> Explore action 5
#                 Node 127: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 5 returned 3
#               -> Explore action 0
#                 Node 128: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 0 returned 3
#               -> Explore action 6
#                 Node 129: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 6 returned 3
#               -> Explore action 2
#                 Node 130: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 2 returned 1
#               -> Explore action 4
#                 Node 131: depth=0 player=MAX alpha=0 beta=1 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 4 returned 1
#               -> Explore action 3
#                 Node 132: depth=0 player=MAX alpha=0 beta=1 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 3 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 3
#               => Node 125 returns (val=0, act=3)
#           <- Action 3 returned 0
#           -> Explore action 0
#             Node 133: depth=1 player=MIN alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 134: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 6
#                 Node 135: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 4
#                 Node 136: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 133 returns (val=0, act=4)
#           <- Action 0 returned 0
#           -> Explore action 6
#             Node 137: depth=1 player=MIN alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 138: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 1 returned 2
#               -> Explore action 0
#                 Node 139: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 0 returned 2
#               -> Explore action 2
#                 Node 140: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 137 returns (val=0, act=2)
#           <- Action 6 returned 0
#           => Node 99 returns (val=0, act=2)
#       <- Action 3 returned 0
#       => Node 1 returns (val=0, act=3)
#   <- Action 3 returned 0
#   -> Explore action 2
#     Node 141: depth=3 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 142: depth=2 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 143: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 6
#                 Node 144: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 9
#               <- Action 6 returned 9
#               -> Explore action 2
#                 Node 145: depth=0 player=MAX alpha=0 beta=9 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 2 returned 7
#               -> Explore action 5
#                 Node 146: depth=0 player=MAX alpha=0 beta=7 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 5 returned 7
#               -> Explore action 0
#                 Node 147: depth=0 player=MAX alpha=0 beta=7 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 7
#               <- Action 0 returned 7
#               -> Explore action 4
#                 Node 148: depth=0 player=MAX alpha=0 beta=7 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 4 returned 5
#               -> Explore action 1
#                 Node 149: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 1 returned 3
#               -> Explore action 3
#                 Node 150: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 3 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 3
#               => Node 143 returns (val=0, act=3)
#           <- Action 3 returned 0
#           -> Explore action 4
#             Node 151: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 0
#                 Node 152: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 0 returned 4
#               -> Explore action 6
#                 Node 153: depth=0 player=MAX alpha=0 beta=4 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 6 returned 4
#               -> Explore action 2
#                 Node 154: depth=0 player=MAX alpha=0 beta=4 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 2 returned 2
#               -> Explore action 5
#                 Node 155: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 4
#                 Node 156: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 151 returns (val=0, act=4)
#           <- Action 4 returned 0
#           -> Explore action 1
#             Node 157: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 158: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 5 returned 4
#               -> Explore action 6
#                 Node 159: depth=0 player=MAX alpha=0 beta=4 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 4
#               <- Action 6 returned 4
#               -> Explore action 2
#                 Node 160: depth=0 player=MAX alpha=0 beta=4 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 2 returned 2
#               -> Explore action 4
#                 Node 161: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 4 returned 2
#               -> Explore action 0
#                 Node 162: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 0 returned 2
#               -> Explore action 1
#                 Node 163: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 1 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 1
#               => Node 157 returns (val=0, act=1)
#           <- Action 1 returned 0
#           -> Explore action 5
#             Node 164: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 0
#                 Node 165: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 0 returned 2
#               -> Explore action 6
#                 Node 166: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 167: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 164 returns (val=0, act=2)
#           <- Action 5 returned 0
#           -> Explore action 0
#             Node 168: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 169: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 4 returned 2
#               -> Explore action 5
#                 Node 170: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 6
#                 Node 171: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 172: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 168 returns (val=0, act=2)
#           <- Action 0 returned 0
#           -> Explore action 2
#             Node 173: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 174: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 173 returns (val=0, act=2)
#           <- Action 2 returned 0
#           -> Explore action 6
#             Node 175: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 176: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 175 returns (val=0, act=4)
#           <- Action 6 returned 0
#           => Node 142 returns (val=0, act=3)
#       <- Action 2 returned 0
#       ## CUTOFF (alpha=0 >= beta=0) after action 2
#       => Node 141 returns (val=0, act=2)
#   <- Action 2 returned 0
#   -> Explore action 4
#     Node 177: depth=3 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 178: depth=2 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 179: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 180: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 4 returned 5
#               -> Explore action 1
#                 Node 181: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 0
#                 Node 182: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 2
#                 Node 183: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 2 returned 3
#               -> Explore action 5
#                 Node 184: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 5 returned 3
#               -> Explore action 6
#                 Node 185: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 6 returned 3
#               -> Explore action 3
#                 Node 186: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 3 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 3
#               => Node 179 returns (val=0, act=3)
#           <- Action 3 returned 0
#           -> Explore action 4
#             Node 187: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 188: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 6
#                 Node 189: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 190: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 187 returns (val=0, act=2)
#           <- Action 4 returned 0
#           -> Explore action 5
#             Node 191: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 192: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 4 returned 2
#               -> Explore action 5
#                 Node 193: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 2
#                 Node 194: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 191 returns (val=0, act=2)
#           <- Action 5 returned 0
#           -> Explore action 6
#             Node 195: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 196: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 4 returned 2
#               -> Explore action 6
#                 Node 197: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 198: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 195 returns (val=0, act=2)
#           <- Action 6 returned 0
#           -> Explore action 2
#             Node 199: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 200: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 199 returns (val=0, act=2)
#           <- Action 2 returned 0
#           -> Explore action 1
#             Node 201: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 202: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 201 returns (val=0, act=4)
#           <- Action 1 returned 0
#           -> Explore action 0
#             Node 203: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 204: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 203 returns (val=0, act=4)
#           <- Action 0 returned 0
#           => Node 178 returns (val=0, act=3)
#       <- Action 2 returned 0
#       ## CUTOFF (alpha=0 >= beta=0) after action 2
#       => Node 177 returns (val=0, act=2)
#   <- Action 4 returned 0
#   -> Explore action 1
#     Node 205: depth=3 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 206: depth=2 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 207: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 208: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 4 returned 3
#               -> Explore action 1
#                 Node 209: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 1 returned 3
#               -> Explore action 5
#                 Node 210: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 5 returned 3
#               -> Explore action 0
#                 Node 211: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 0 returned 3
#               -> Explore action 6
#                 Node 212: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 6 returned 3
#               -> Explore action 2
#                 Node 213: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 2 returned 1
#               -> Explore action 3
#                 Node 214: depth=0 player=MAX alpha=0 beta=1 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = -2
#               <- Action 3 returned -2
#               ## CUTOFF (alpha=0 >= beta=-2) after action 3
#               => Node 207 returns (val=-2, act=3)
#           <- Action 3 returned -2
#           -> Explore action 2
#             Node 215: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 216: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 2 returned 2
#               -> Explore action 1
#                 Node 217: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 1 returned 2
#               -> Explore action 0
#                 Node 218: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 0 returned 2
#               -> Explore action 6
#                 Node 219: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 4
#                 Node 220: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 215 returns (val=0, act=4)
#           <- Action 2 returned 0
#           -> Explore action 1
#             Node 221: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 0
#                 Node 222: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 0 returned 2
#               -> Explore action 6
#                 Node 223: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 224: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 221 returns (val=0, act=2)
#           <- Action 1 returned 0
#           -> Explore action 4
#             Node 225: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 226: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 225 returns (val=0, act=4)
#           <- Action 4 returned 0
#           -> Explore action 5
#             Node 227: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 228: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 227 returns (val=0, act=4)
#           <- Action 5 returned 0
#           -> Explore action 0
#             Node 229: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 230: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 1 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 1
#               => Node 229 returns (val=0, act=1)
#           <- Action 0 returned 0
#           -> Explore action 6
#             Node 231: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 232: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 1 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 1
#               => Node 231 returns (val=0, act=1)
#           <- Action 6 returned 0
#           => Node 206 returns (val=0, act=2)
#       <- Action 2 returned 0
#       ## CUTOFF (alpha=0 >= beta=0) after action 2
#       => Node 205 returns (val=0, act=2)
#   <- Action 1 returned 0
#   -> Explore action 5
#     Node 233: depth=3 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 234: depth=2 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 235: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 236: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 5
#                 Node 237: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 5 returned 5
#               -> Explore action 0
#                 Node 238: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 2
#                 Node 239: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 2 returned 3
#               -> Explore action 4
#                 Node 240: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 4 returned 3
#               -> Explore action 6
#                 Node 241: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 6 returned 3
#               -> Explore action 3
#                 Node 242: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 3 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 3
#               => Node 235 returns (val=0, act=3)
#           <- Action 3 returned 0
#           -> Explore action 4
#             Node 243: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 244: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 4 returned 2
#               -> Explore action 5
#                 Node 245: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 2
#                 Node 246: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 243 returns (val=0, act=2)
#           <- Action 4 returned 0
#           -> Explore action 5
#             Node 247: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 6
#                 Node 248: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 249: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 247 returns (val=0, act=2)
#           <- Action 5 returned 0
#           -> Explore action 6
#             Node 250: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 251: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 6
#                 Node 252: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 253: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 250 returns (val=0, act=2)
#           <- Action 6 returned 0
#           -> Explore action 2
#             Node 254: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 255: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 254 returns (val=0, act=2)
#           <- Action 2 returned 0
#           -> Explore action 1
#             Node 256: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 257: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 256 returns (val=0, act=4)
#           <- Action 1 returned 0
#           -> Explore action 0
#             Node 258: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 259: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 5 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 5
#               => Node 258 returns (val=0, act=5)
#           <- Action 0 returned 0
#           => Node 234 returns (val=0, act=3)
#       <- Action 2 returned 0
#       ## CUTOFF (alpha=0 >= beta=0) after action 2
#       => Node 233 returns (val=0, act=2)
#   <- Action 5 returned 0
#   -> Explore action 0
#     Node 260: depth=3 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 261: depth=2 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 262: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 263: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 4 returned 3
#               -> Explore action 1
#                 Node 264: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 1 returned 3
#               -> Explore action 5
#                 Node 265: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 5 returned 3
#               -> Explore action 0
#                 Node 266: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 0 returned 3
#               -> Explore action 6
#                 Node 267: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 6 returned 3
#               -> Explore action 2
#                 Node 268: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 1
#               <- Action 2 returned 1
#               -> Explore action 3
#                 Node 269: depth=0 player=MAX alpha=0 beta=1 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = -2
#               <- Action 3 returned -2
#               ## CUTOFF (alpha=0 >= beta=-2) after action 3
#               => Node 262 returns (val=-2, act=3)
#           <- Action 3 returned -2
#           -> Explore action 0
#             Node 270: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 6
#                 Node 271: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 272: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 270 returns (val=0, act=2)
#           <- Action 0 returned 0
#           -> Explore action 2
#             Node 273: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 274: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 273 returns (val=0, act=2)
#           <- Action 2 returned 0
#           -> Explore action 4
#             Node 275: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 276: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 4 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 4
#               => Node 275 returns (val=0, act=4)
#           <- Action 4 returned 0
#           -> Explore action 1
#             Node 277: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 278: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 1 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 1
#               => Node 277 returns (val=0, act=1)
#           <- Action 1 returned 0
#           -> Explore action 5
#             Node 279: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 280: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 5 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 5
#               => Node 279 returns (val=0, act=5)
#           <- Action 5 returned 0
#           -> Explore action 6
#             Node 281: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 0
#                 Node 282: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 0 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 0
#               => Node 281 returns (val=0, act=0)
#           <- Action 6 returned 0
#           => Node 261 returns (val=0, act=0)
#       <- Action 2 returned 0
#       ## CUTOFF (alpha=0 >= beta=0) after action 2
#       => Node 260 returns (val=0, act=2)
#   <- Action 0 returned 0
#   -> Explore action 6
#     Node 283: depth=3 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#       -> Explore action 2
#         Node 284: depth=2 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#           -> Explore action 3
#             Node 285: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 286: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 1 returned 5
#               -> Explore action 0
#                 Node 287: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 0 returned 5
#               -> Explore action 6
#                 Node 288: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 5
#               <- Action 6 returned 5
#               -> Explore action 2
#                 Node 289: depth=0 player=MAX alpha=0 beta=5 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 2 returned 3
#               -> Explore action 4
#                 Node 290: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 4 returned 3
#               -> Explore action 5
#                 Node 291: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 3
#               <- Action 5 returned 3
#               -> Explore action 3
#                 Node 292: depth=0 player=MAX alpha=0 beta=3 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 3 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 3
#               => Node 285 returns (val=0, act=3)
#           <- Action 3 returned 0
#           -> Explore action 4
#             Node 293: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 4
#                 Node 294: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 4 returned 2
#               -> Explore action 6
#                 Node 295: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 296: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 293 returns (val=0, act=2)
#           <- Action 4 returned 0
#           -> Explore action 5
#             Node 297: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 5
#                 Node 298: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 5 returned 2
#               -> Explore action 6
#                 Node 299: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 2
#               <- Action 6 returned 2
#               -> Explore action 2
#                 Node 300: depth=0 player=MAX alpha=0 beta=2 legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 297 returns (val=0, act=2)
#           <- Action 5 returned 0
#           -> Explore action 6
#             Node 301: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 302: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 301 returns (val=0, act=2)
#           <- Action 6 returned 0
#           -> Explore action 2
#             Node 303: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 2
#                 Node 304: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 2 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 2
#               => Node 303 returns (val=0, act=2)
#           <- Action 2 returned 0
#           -> Explore action 1
#             Node 305: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 1
#                 Node 306: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 1 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 1
#               => Node 305 returns (val=0, act=1)
#           <- Action 1 returned 0
#           -> Explore action 0
#             Node 307: depth=1 player=MIN alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#               -> Explore action 0
#                 Node 308: depth=0 player=MAX alpha=0 beta=inf legal=[0, 1, 2, 3, 4, 5, 6]
#                   -> Leaf eval = 0
#               <- Action 0 returned 0
#               ## CUTOFF (alpha=0 >= beta=0) after action 0
#               => Node 307 returns (val=0, act=0)
#           <- Action 0 returned 0
#           => Node 284 returns (val=0, act=3)
#       <- Action 2 returned 0
#       ## CUTOFF (alpha=0 >= beta=0) after action 2
#       => Node 283 returns (val=0, act=2)
#   <- Action 6 returned 0
#   => Node 0 returns (val=0, act=3)
# === TRACE END ===
# Result: chosen action=3, value=0, nodes=309, cutoffs=65
